# %% [markdown]
# 5. Za določanje vrednosti uteži v nevronskih mrežah SGD potrebujemo vrednosti gradientov. (15 točk)
#    5.a Katerih?
#    5.b Kako jih določimo (z nekaj besedami)?
#    5.c Zakaj je ravno SGD najbolj uporabljena metoda za določanje vrednosti uteži?
#
# 6. Non-negative matrix factorization (NMF) (15 točk)
#    6.a Kaj je rezultat NMF?
#    6.b Kako "rešujemo" NMF?
#    6.c NMF se ponavadi uporablja za izdelavo priporočilnih sistemov. Želimo izdelati priporočilni sistem za trgovino s produkti za male živali. Katere podatke bi dali algoritmu NMF (v matriko) in razmislite predstavljal rezultat?
#
# Narišite preprosto polno povezano nevronsko mrežo s tremi vhodi, z dvema skritima nivojema in izhodno plastjo za primer klasifikacije podatkov v tri razrede. (25 točk)
#    a. Definirajte aktivacijske funkcije v skritih plasteh.
#    b. Definirajte izhodno plast. Od česa je odvisna?
#    c. Inicializirajte uteži. Kako ste vrednosti določili?
#
#
#
# 5. Želimo rešiti primer klasifikacije (glej sliko 5). Napovedujemo dva razreda (dve barvi krogcev na sliki).
#    - Kateri model bi uporabili? Opišite ga.
#    - Kakšne hiperparametre bi nastavili, oziroma kako bi jih določili?
#    - Narišite meje, ki bi jih izbrani klasifikator ustvaril.
#
# Figure 1: Slika naloge 5.
#
# Drugi kolokvij
# 1. Na sliki 1 je enostavna nevronska mreža (20 točk)
#    a. Kateri so v splošnem koraki, ki jih izvedemo, ko učimo nevronske mreže?
#    b. Predpostavimo, da je i1=5, i2=3, pričakovan izhod pa je enak 1. Aktivacijska funkcija skrite plasti je sigmoidna funkcija, izhodni nevron pa predstavlja le linearno funkcijo. Izračunaj napako, ki jo dobimo na izhodu (pazite na inicializacijo uteži) pri prvem prehodu skozi nevronsko mrežo. Napaka je določena kot kvadratična napaka.
#    c. Kako določimo začetne vrednosti uteži?
#    d. Kje bo težava v spodnjem primeru, če inicializiramo uteži na zelo velike ali zelo majhne vrednosti?
#    e. Izpeljite enačbe za parametre nevrona izhodne plasti in zgornjega nevrona (h1) skrite plasti z vzvratnim razširjanjem napake. Aktivacijske funkcije so iste kot v prejšnji točki (b).
#
# Figure 1: Slika nevronske mreže.
#
# 2. Gaussovi procesi (10 točk)
#    a. Kaj je rezultat modeliranja z Gaussovimi procesi (npr. rezultat linearne regresije je enačba premice)?
#    b. Kaj predstavlja posamezno napoved pri modeliranju z Gaussovimi procesi?
#    c. Gaussov proces učimo s pomočjo zaporedjem točk podanih v tabeli 1 (napovedujemo y s pomočjo x). Narišite rezultat Gaussovega procesa za primer, ko
#
# | X | 2 | 5 | 6 | 7 | 5 |
# |---|---|---|---|---|---|
# | y | 1 | 1 | 5 | 2 | 3 |
#
# Table 1: Tabela za Gaussov proces.
#
# Gaussov proces ne upošteva prisotnosti šuma in za primer, ko upošteva šum. Narišite napovedi (y) za točki x = 3.5 in x = 6.5.
#
# 3. S pomočjo transformerja želimo modelirati stavek "Spretna lisica je skočila čez lenega psa.". Zakaj so uporabni naslednji deli transformerja: Self-Attention, Multi-Head Attention, Positional Encoding, Feedforward Neural Network? (Pomisli, kaj navedene komponente delajo).
#
# 4. Imamo enačbo linearne regresije s katero modeliramo težo oseb Weight = 0.5 * Age + 87 * Height + 3 * BMI + 148. Kjer smo uporabili podatke o starosti v letih, višine v metrih, teže v kilogramih in BMI v kg/m².
#    a. Kako interpretiramo koeficiente?
#    b. Ali lahko velikosti koeficientov primerjamo med seboj? Argumentirajte oziroma predlagajte rešitev.
#    c. Glede na uporabljene atribute, kaj je težava pri interpretaciji?
